# %% [markdown]
# Converting Guerreiro et al. 2014 data from pdf to csv

# %%
#pip install --user tabula-py
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/cf/29/d6cb0d77ef46d84d35cffa09cf42c73b373aea664d28604eab6818f8a47c/tabula_py-2.2.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/25/b7/b3c4270a11414cb22c6352ebc7a83aaa3712043be29daa05018fd5a5c956/distro-1.5.0-py2.py3-none-any.whl
# ...
#   WARNING: The script distro is installed in '/Users/ar19/Library/Python/3.8/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
# WARNING: You are using pip version 19.2.3, however version 21.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import tabula

# %%
file = "/Users/ar19/Desktop/Gametocytogenesis/data/Reference/raw_data_and_merging_scripts/Guerreiro_2014.pdf"
tabula.convert_into(file, "output.csv", output_format="csv", pages='all')
# Out:
# Got stderr: Apr 11, 2021 3:23:42 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: Your current java version is: 1.8.0_131
# Apr 11, 2021 3:23:43 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: To get higher rendering speed on old java 1.8 or 9 versions,
# Apr 11, 2021 3:23:43 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   update to the latest 1.8 or 9 version (>= 1.8.0_191 or >= 9.0.4),
# Apr 11, 2021 3:23:43 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or
# Apr 11, 2021 3:23:43 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProvider
# Apr 11, 2021 3:23:43 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or call System.setProperty("sun.java2d.cmm", "sun.java2d.cmm.kcms.KcmsServiceProvider")
#            PBANKA                        Product Description DOZI/WT  \
# ...

# %% [markdown]
# Then fix any errors in csv manually
